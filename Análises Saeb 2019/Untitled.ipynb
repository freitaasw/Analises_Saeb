# %%
# !pip install plotly_express

# %%
import plotly
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd
df = pd.read_excel('TS_UF.xlsx')
df.head(20)
# Out:
#     CO_UF     NO_UF DEPENDENCIA_ADM LOCALIZACAO   CAPITAL  MEDIA_2_LP  \
# 0      11  Rondônia        Estadual       Rural   Capital         NaN
# 1      11  Rondônia        Estadual       Rural  Interior      739.77
# 2      11  Rondônia        Estadual       Rural     Total      739.77
# 3      11  Rondônia        Estadual       Total   Capital      741.65
# 4      11  Rondônia        Estadual       Total  Interior      742.27
# 5      11  Rondônia        Estadual       Total     Total      742.06
# 6      11  Rondônia        Estadual      Urbana   Capital      741.65
# 7      11  Rondônia        Estadual      Urbana  Interior      742.49
# 8      11  Rondônia        Estadual      Urbana     Total      742.20
# 9      11  Rondônia         Federal       Rural  Interior         NaN
# 10     11  Rondônia         Federal       Rural     Total         NaN
# 11     11  Rondônia         Federal       Total   Capital         NaN
# ...

# %%
df.shape
# Out:
# (1550, 156)

# %%
df_regioes = df.iloc[:,:13]
df_regioes.head()
# Out:
#    CO_UF     NO_UF DEPENDENCIA_ADM LOCALIZACAO   CAPITAL  MEDIA_2_LP  \
# 0     11  Rondônia        Estadual       Rural   Capital         NaN
# 1     11  Rondônia        Estadual       Rural  Interior      739.77
# 2     11  Rondônia        Estadual       Rural     Total      739.77
# 3     11  Rondônia        Estadual       Total   Capital      741.65
# 4     11  Rondônia        Estadual       Total  Interior      742.27
#
#    MEDIA_2_MT  MEDIA_5_LP  MEDIA_5_MT  MEDIA_9_LP  MEDIA_9_MT  MEDIA_9_CH  \
# 0         NaN      196.52      204.66      244.41      250.68      248.53
# 1      703.07      171.98      172.51      246.38      256.35        0.00
# 2      703.07      192.80      199.79      245.52      253.88      248.53
# 3      732.84      207.89      217.00      249.49      248.49      243.64
# 4      738.61      208.66      225.27      256.13      260.64      247.84
#
#    MEDIA_9_CN
# 0      223.51
# 1        0.00
# 2      223.51
# 3      247.91
# 4      249.46
